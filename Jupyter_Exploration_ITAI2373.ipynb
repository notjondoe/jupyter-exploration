# %% [markdown]
# Hello, this is not first markdown, I am fairly familair with Jupyter and GitHub.

# %%
print("Hello I am looking for to taking this course! I am excited as this is my first ITAI 2000 course.")
