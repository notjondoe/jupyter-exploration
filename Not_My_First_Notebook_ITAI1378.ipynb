# %% [markdown]
# Hello, I am looking forward for your course this fall semester!

# %%
print("I am excited for all the learning experiences andbeing able to use my previous learning in this course!")
