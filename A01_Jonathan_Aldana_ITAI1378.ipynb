# %% [markdown]
# My first markdown cell in this Jupyter notebook.

# %%
print("I am fairly familiar with Jupyter as I have used it for my previous courses.")
# Out:
# I am fairly familiar with Jupyter as I used it for my previous courses.
